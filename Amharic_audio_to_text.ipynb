# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahg39/Python/blob/main/Amharic_audio_to_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai-whisper ffmpeg pydub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 10.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

#let the user upload an audio file from their computer
uploaded = files.upload()   #opens file upload dialog

#get the uploaded file's name
audio_path = list(uploaded.keys())[0]

print("👍 uploaded file", audio_path)
# Out:
#      <input type="file" id="files-3e34a7ca-1f05-4c75-805a-250cd0043a17" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e34a7ca-1f05-4c75-805a-250cd0043a17">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install -U openai-whisper ffmpeg pydub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 10.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...

# %%
import whisper

# Load the Whisper model (small is best for Amharic)
model = whisper.load_model("small")

print("✅ Whisper installed and model loaded successfully!")
# Out:
# 100%|████████████████████████████████████████| 461M/461M [00:04<00:00, 117MiB/s]
# ...

# %%
import whisper

#Load the whisper model (small or medium)
model = whisper.load.model("small")

#Transcribe the converted WAV file
result = model.transcribe(converted_wav, language="am")

#Extract the recognized Amharic text
amharic_text = result["text"]

print("Recognized Amharic Text:")
print(amharic_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-ed782085ceb6> in <cell line: 0>()
#       2
#       3 #Load the whisper model (small or medium)
# ----> 4 model = whisper.load.model("small")
#       5
#       6 #Transcribe the converted WAV file
#
# AttributeError: module 'whisper' has no attribute 'load'

# %%
# !kill -9 -1

# %%
# !pip uninstall -y whisper
# Out:
# WARNING: Skipping whisper as it is not installed.

# %%
# !pip install SpeechRecognition pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 47.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

# Upload an audio file
uploaded = files.upload()

# Get the file name
audio_path = list(uploaded.keys())[0]
print("✅ Uploaded file:", audio_path)
# Out:
#      <input type="file" id="files-ccba01aa-69d3-4f94-ae5e-a6f96cd91079" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ccba01aa-69d3-4f94-ae5e-a6f96cd91079">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pydub import AudioSegment

#Load the audio file
audio = AudioSegment.from_file(audio_path)

#convert to WAV format (16khz, mono)
converted_wav = "converted.wav"
audio = audio.set_channels(1).set_frame_rate(16000)
audio.export(converted_wav, format="wav")

print("✅ Audio converted to WAV format successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e9bd46d6e280> in <cell line: 0>()
# ----> 1 from pydub import AudioSegment
#       2
#       3 #Load the audio file
#       4 audio = AudioSegment.from_file(audio_path)
#       5
#
# ModuleNotFoundError: No module named 'pydub'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import speech_recognition as sr

# Initialize the recognizer
recognizer = sr.Recognizer()

#Load the audio file
with sr.AudioFile(converted_wav) as source:
    print("processing audio... please wait")
    audio_data = recognizer.record(source)  #record thw full audio file

#recognize speech using Google's API
try:
    amharic_text = recognizer.recognize_google(audio_data, language="am-ET")
    print("/n Recognized Amharic Text:", amharic_text)
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand the audio.")
except sr.RequestError:
    print("Could not request results from Google Speech Recognition service.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-e9973acf78de> in <cell line: 0>()
# ----> 1 import speech_recognition as sr
#       2
#       3 # Initialize the recognizer
#       4 recognizer = sr.Recognizer()
#       5
#
# ModuleNotFoundError: No module named 'speech_recognition'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install SpeechRecognition pydub ffmpeg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 32.2 MB/s eta 0:00:00
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=763188cb9fdf63e44aa4cbab26523e9d7f15485fbe6c5ab105feb4090d0249ed
#   Stored in directory: /root/.cache/pip/wheels/56/30/c5/576bdd729f3bc062d62a551be7fefd6ed2f761901568171e4e
# Successfully built ffmpeg
# ...

# %%
import speech_recognition as sr
from pydub import AudioSegment

print("✅ All packages installed successfully!")
# Out:
# ✅ All packages installed successfully!

# %%
from google.colab import files

# Upload an audio file from your computer
uploaded = files.upload()

# Get the file name from uploaded files
audio_path = list(uploaded.keys())[0]
print("✅ Uploaded file:", audio_path)
# Out:
#      <input type="file" id="files-f237df29-dd2b-4370-92b2-3eb84cdd8a29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f237df29-dd2b-4370-92b2-3eb84cdd8a29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pydub import AudioSegment

# Load the uploaded audio file
audio = AudioSegment.from_file(audio_path)

# Convert to WAV format (16kHz, mono)
converted_wav = "converted.wav"
audio = audio.set_channels(1).set_frame_rate(16000)
audio.export(converted_wav, format="wav")

print("✅ Audio converted successfully:", converted_wav)
# Out:
# ✅ Audio converted successfully: converted.wav

# %%
import speech_recognition as sr

# Initialize recognizer
recognizer = sr.Recognizer()

# Load the audio file
with sr.AudioFile(converted_wav) as source:
    print("🎤 Processing audio... Please wait...")
    audio_data = recognizer.record(source)  # Record the full audio file

# Recognize speech using Google's API
try:
    amharic_text = recognizer.recognize_google(audio_data, language="am-ET")
    print("\n📜 Recognized Amharic Text:\n", amharic_text)
except sr.UnknownValueError:
    print("😕 Could not understand the audio")
except sr.RequestError:
    print("⚠️ Could not request results from Google’s Speech API")
# Out:
# 🎤 Processing audio... Please wait...
#
# 📜 Recognized Amharic Text:
#  ማጠቃለያ የነርጂ ለዘላቂ ዓለም ኢነርጂ ለዝብ ቻላልም የልብ ምትነው ግን አሁን እንዴት እንጠቀመዋለን የሚለው ለሚመጣው ጊዜ ወሳኝ ነው እንዴት እናበርክ ለሚለው ደሞ እንሆ ኢነርጂ መቆጠብ ገንዘብን መቆጣጠር ብቻ አይደለም ለወደፊቱ ልጆች ሃብቶችን ማረጋገጥ ነው። ጉልበት በምናባክንበት ጊዜ ለብስ ለታስተዋጾ እናረጋለን እናም ጠቃሚ የተፈጥሮ ሃብቶችና እጠፋለን ቀላለው ጠጅ እንደ በማንፈልገው ሰዓት መብራቶችን ማጥፋት ወይም ሀይል ወጣ በመሳሪያዎችን መምረጥ ትልቅ ለውጥ ያመጣል ለሚታደሰ ኃይሎች መስራት የተቻልን እናስተዋጽኦ ማድረግ ሰብስክራይብ በማድረግ ቀጣይ video የጠብቁ እናመሰግናለን ይከታተሉ
