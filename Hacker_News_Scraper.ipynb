# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.ycombinator.com/"
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

articles = soup.select('.titleline > a')    #'.titleline > a' means: "find every <a> tag inside a class='titleline'"

print("🔥 Top Hacker News Headlines 🔥\n")

for i, article in enumerate(articles):
    title = article.text.strip()

    link = article['href']

    print(f"{i+1}. {title}")
    print(f" 🔗 {link}\n")
# Out:
# 🔥 Top Hacker News Headlines 🔥
#
# 1. Embeddings Are Underrated
#  🔗 https://technicalwriting.dev/ml/embeddings/overview.html
#
# 2. The Barbican
#  🔗 https://arslan.io/2025/05/12/barbican-estate/
#
# 3. HealthBench
#  🔗 https://openai.com/index/healthbench/
#
# 4. RIP Usenix ATC
#  🔗 https://bcantrill.dtrace.org/2025/05/11/rip-usenix-atc/
#
# 5. Launch HN: ParaQuery (YC X25) – GPU Accelerated Spark/SQL
#  🔗 item?id=43964505
#
# 6. Show HN: Lumoar – Free SOC 2 tool for SaaS startups
#  🔗 https://www.lumoar.com
#
# 7. A community-led fork of Organic Maps
#  🔗 https://www.comaps.app/news/2025-05-12/3/
#
# 8. Byte Latent Transformer: Patches Scale Better Than Tokens
#  🔗 https://arxiv.org/abs/2412.09871
#
# 9. Ruby 3.5 Feature: Namespace on read
#  🔗 https://bugs.ruby-lang.org/issues/21311
#
# 10. Show HN: Airweave – Let agents search any app
#  🔗 https://github.com/airweave-ai/airweave
#
# 11. Legion Health (YC S21) Is Hiring Founding Engineers to Fix Mental Health with AI
#  🔗 https://www.workatastartup.com/jobs/75011
#
# 12. I hacked a dating app (and how not to treat a security researcher)
#  🔗 https://alexschapiro.com/blog/security/vulnerability/2025/04/21/startups-need-to-take-security-seriously
#
# 13. 5 Steps to N-Body Simulation
#  🔗 https://alvinng4.github.io/grav_sim/5_steps_to_n_body_simulation/
#
# 14. Demonstrably Secure Software Supply Chains with Nix
#  🔗 https://nixcademy.com/posts/secure-supply-chain-with-nix/
#
# 15. Why GADTs matter for performance (2015)
#  🔗 https://blog.janestreet.com/why-gadts-matter-for-performance/
#
# 16. Interagency Grizzly Bear Committee
#  🔗 https://igbconline.org/
#
# 17. Tailscale 4via6 – Connect Edge Deployments at Scale
#  🔗 https://tailscale.com/blog/4via6-connectivity-to-edge-devices
#
# 18. Can You Really Trust That Permission Pop-Up on macOS? (CVE-2025-31250)
#  🔗 https://wts.dev/posts/tcc-who/
#
# 19. How to title your blog post or whatever
#  🔗 https://dynomight.net/titles/
#
# 20. University of Texas-led team solves a big problem for fusion energy
#  🔗 https://news.utexas.edu/2025/05/05/university-of-texas-led-team-solves-a-big-problem-for-fusion-energy/
#
# 21. Reviving a Modular Cargo Bike Design from the 1930s
#  🔗 https://www.core77.com/posts/136773/Reviving-a-Modular-Cargo-Bike-Design-from-the-1930s
#
# 22. Universe expected to decay in 10⁷⁸ years, much sooner than previously thought
#  🔗 https://phys.org/news/2025-05-universe-decay-years-sooner-previously.html
#
# 23. Continuous glucose monitors reveal variable glucose responses to the same meals
#  🔗 https://examine.com/research-feed/study/1jjKq1/
#
# 24. Spade Hardware Description Language
#  🔗 https://spade-lang.org/
#
# 25. I ruined my vacation by reverse engineering WSC
#  🔗 https://blog.es3n1n.eu/posts/how-i-ruined-my-vacation/
#
# 26. Toward a Sparse and Interpretable Audio Codec
#  🔗 https://arxiv.org/abs/2505.05654
#
# 27. OpenEoX to Standardize End-of-Life (EOL) and End-of-Support (EOS) Information
#  🔗 https://openeox.org/
#
# 28. The FTC puts off enforcing its 'click-to-cancel' rule
#  🔗 https://www.theverge.com/news/664730/ftc-delay-click-to-cancel-rule
#
# 29. A Typical Workday at a Japanese Hardware Tool Store [video]
#  🔗 https://www.youtube.com/watch?v=A98jyfB5mws
#
# 30. The Internet 1997 – 2021
#  🔗 https://www.opte.org/the-internet
